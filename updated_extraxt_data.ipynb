# %%
import requests
import math
from pprint import pprint
import pandas as pd

# %%
url = "https://www.qantas.com/hotels/api/ui/locations/London,%20England,%20United%20Kingdom/availability?checkIn=2024-08-03&checkOut=2024-08-05&adults=2&children=0&infants=0&sortBy=popularity&propertyTypes=&facilities=&subRegions=&limit=25&payWith=cash&page=2"
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-language': 'en-US,en;q=0.9,ru;q=0.8',
  'cookie': 'pbe_user_id=ea0aebd5-bf82-4fbc-857a-417ea081628c; qh_user_id=bf15eca5-d244-4069-88c8-523136305847; qantas_isDevice=type^#desktop|os^#Windows NT; optimizelyEndUserId=oeu1722229679206r0.11646333370833961; _hjSessionUser_1001219=eyJpZCI6IjY1N2FlNGY5LTI2OTMtNWZhNi05MDZlLTY5MTQwNDQ1M2U1MiIsImNyZWF0ZWQiOjE3MjIyMjk2OTEzNjcsImV4aXN0aW5nIjp0cnVlfQ==; _gid=GA1.2.1711787642.1722229692; _gcl_au=1.1.961780450.1722229692; _y2=1%3AeyJjIjp7IjI1NDA4MCI6MjQ4MzAxNzU0fX0%3D%3ANjQyNTY2MDQ4%3A99; AKA_A2=A; bm_ss=ab8e18ef4e; _abck=A79ED486EEE51E59C4A5BC54F606F111~0~...~-1~-1~-1; initalReferrerHotels=; qtspersisted=_f77dc3521ab54b5f86c47742458edbb9a753692abc39406b9c1cb8e1873662e8_b93cc020b21349f29d3bfe8c88721f42_1722229702289_45035996276881129_1722320155634_5; _hjSession_1001219=eyJpZCI6ImQxMThmNDdjLTYyNTEtNDVkNS1iNzk4LTNmM2VkMjU2MmMyYyIsImMiOjE3MjIzMjAxNTcxMjUsInMiOjEsInIiOjEsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; _ga=GA1.2.265119221.1722229688; _gat_UA-32359880-1=1; _gat_UA-259752839-1=1; qtssession=45035996276881129_1722320219026_1722320155634_2028_9847d5958cde454eb9bf9bcf54dc9593; _yi=1%%3D%3ALTE4MDY5MDc0ODg%3D%3A99; bm_mi=5DAE840BCA0F077464E86735AECBC529~~1; bm_sz=1E6079346337A5ECB0BDFC8D0571FF4D~...~4404034~4473667; RT="z=1&dm=www.qantas.com&si=c2669558-4160-48ec-bbc7-5b848a4e8304&ss=lz80xx9m&sl=b&tt=k51&bcn=%2F%2F684d0d4a.akstat.io%2F&ld=1uwa&ul=201q&hd=20sv"; _ga_2JVDJ9RW0S=GS1.1.1722320153.6.1.1722320234.60.0.0; ak_bmsc=9DA1CFDBC79FF8BD89CFCA8A74E8FB55~000000000000000000000000000000~...; bm_s=; bm_sv=CEBA9C6F1894ABC63F90111B582352AD~~1; _abck=A79ED486EEE51E59C4A5BC54F606F111~-1~~0~-1~-1; bm_s=; usercontext=region#AS|country#IN|locale#en|dep#BOM',
  'if-none-match': 'W/"1c576-PdPkPW3jXe5pNfbffBGYrO0JI3U"',
  'priority': 'u=1, i',
  'qh-meta': '{"qhUserId":"bf15eca5-d244-4069-88c8-523136305847"}',
  'referer': 'https://www.qantas.com/hotels/properties/18482?adults=2&checkIn=2024-08-13&checkOut=2024-08-14&children=0&infants=0&location=London%2C%20England%2C%20United%20Kingdom&page=1&payWith=cash&searchType=list&sortBy=popularity',
  'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'sentry-trace': 'd5de18dfc2af4aa0b7c0c9efd8e32579-821d5b6e8ad3b06e-1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}
response = requests.request("GET", url, headers=headers)

# %%
id_data=response.json()

# %%
hotel_ids=[]
for ids in id_data['results']:
    hotel_ids.append(ids['property']['id'])
print(hotel_ids)
# Out:
# ['21416', '192053', '100425', '18620', '961500', '19839', '21498', '21358', '18608', '439474', '767812', '19755', '19660', '779486', '849561', '18508', '465412', '21562', '99214', '180971', '21734', '194496', '713813', '19800', '224854']

# %%
import random
from datetime import datetime, timedelta

def generate_random_dates_for_aug_sept(start_date, end_date, num_pairs):
    date_pairs = []
    days_between_dates = (end_date - start_date).days

    for _ in range(num_pairs):
        random_days_for_checkin = random.randint(0, days_between_dates)
        checkin_date = start_date + timedelta(days=random_days_for_checkin)
        checkout_duration = random.randint(2, 3)
        checkout_date = checkin_date + timedelta(days=checkout_duration)
        if checkout_date > end_date:
            checkout_date = end_date
        date_pairs.append((checkin_date, checkout_date))
    return date_pairs

start_date = datetime(2024, 8, 1)
end_date = datetime(2024, 9, 30)

random_date_pairs = generate_random_dates_for_aug_sept(start_date, end_date, 25)
checkin_date=[]
checkout_date=[]

for i, (checkin, checkout) in enumerate(random_date_pairs, start=1):
    checkin_date.append(checkin.strftime('%Y-%m-%d'))
    checkout_date.append(checkout.strftime('%Y-%m-%d'))

# %%
def extract_data(data):
    rates=[]
    count=0
    for rooms in data['roomTypes']:
        for d in rooms['offers']:
            count+=1
            rate_info = {
            'Room_name': rooms['name'],
            'Rate_name': d['description'],
            'Number of Guests': int(data['meta']['query']['children'])+int(data['meta']['query']['infants'])+int(data['meta']['query']['adults']),
            'Cancellation Policy': 'Non-refundable' if d['cancellationPolicy']['isNonrefundable'] else d['cancellationPolicy']['description'],
            'Price': math.ceil(float(d['charges']['total']['amount'])),
            'Currency': d['charges']['total']['currency'],
            'Top Deal': True if d['promotion'] else False
            }
            rates.append(rate_info)
    rates={data['id']:rates}
    pprint(rates)
    json_data={
        "hotel_id":data['id'],
        "check-in":str(data['meta']['query']['checkIn']),
        "check-out":str(data['meta']['query']['checkOut']),
        "rates":rates
    }
    df = pd.DataFrame([json_data])
    df.to_csv(r"C:\Users\goura\Downloads\output.csv", index=False, header=None, mode='a')

# %%
for id,checkIn,checkOut in zip(hotel_ids, checkin_date, checkout_date):
    url = f"https://www.qantas.com/hotels/api/ui/properties/{id}/availability?checkIn={checkIn}&checkOut={checkOut}&adults=2&children=0&infants=0&payWith=cash"
    response = requests.request("GET", url, headers=headers)
    extract_data(response.json())
# Out:
# {'21416': [{'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 676,
#             'Rate_name': 'Internet Included - Non-refundable',
#             'Room_name': 'Small Double Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 804,
#             'Rate_name': 'Internet Included',
#             'Room_name': 'Small Double Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 933,
#             'Rate_name': 'Breakfast Included, Internet Included',
#             'Room_name': 'Small Double Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 878,
#             'Rate_name': 'Internet Included - Non-refundable',
#             'Room_name': 'Superior Double Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1045,
#             'Rate_name': 'Internet Included',
#             'Room_name': 'Superior Double Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1174,
#             'Rate_name': 'Breakfast Included, Internet Included',
#             'Room_name': 'Superior Double Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 878,
#             'Rate_name': 'Internet Included - Non-refundable',
#             'Room_name': 'Superior Twin Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1045,
#             'Rate_name': 'Internet Included',
#             'Room_name': 'Superior Twin Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1174,
#             'Rate_name': 'Breakfast Included, Internet Included',
#             'Room_name': 'Superior Twin Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1013,
#             'Rate_name': 'Internet Included - Non-refundable',
#             'Room_name': 'Club King Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1206,
#             'Rate_name': 'Internet Included',
#             'Room_name': 'Club King Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 19, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1335,
#             'Rate_name': 'Breakfast Included, Internet Included',
#             'Room_name': 'Club King Room',
#             'Top Deal': True}]}
# {'192053': [{'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2214,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Standard Double Room, 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2473,
#              'Rate_name': 'Breakfast Included, Internet Included - '
#                           'Non-refundable',
#              'Room_name': 'Standard Double Room, 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2605,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Standard Double Room, 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2864,
#              'Rate_name': 'Breakfast Included, Internet Included',
#              'Room_name': 'Standard Double Room, 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2895,
#              'Rate_name': 'Breakfast Included, Internet Included, Meal '
#                           'Included - Non-refundable',
#              'Room_name': 'Standard Double Room, 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2522,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Deluxe Double Room, 1 Double Bed, Garden View',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2781,
#              'Rate_name': 'Breakfast Included, Internet Included - '
#                           'Non-refundable',
#              'Room_name': 'Deluxe Double Room, 1 Double Bed, Garden View',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2968,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Deluxe Double Room, 1 Double Bed, Garden View',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 3186,
#              'Rate_name': 'Breakfast Included, Internet Included, Meal '
#                           'Included - Non-refundable',
#              'Room_name': 'Deluxe Double Room, 1 Double Bed, Garden View',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 3227,
#              'Rate_name': 'Breakfast Included, Internet Included',
#              'Room_name': 'Deluxe Double Room, 1 Double Bed, Garden View',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2689,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'River View Room 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 2948,
#              'Rate_name': 'Breakfast Included, Internet Included - '
#                           'Non-refundable',
#              'Room_name': 'River View Room 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 3164,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'River View Room 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 3343,
#              'Rate_name': 'Breakfast Included, Internet Included, Meal '
#                           'Included - Non-refundable',
#              'Room_name': 'River View Room 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 3423,
#              'Rate_name': 'Breakfast Included, Internet Included',
#              'Room_name': 'River View Room 1 Double Bed',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 5941,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Tower Suite',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 6200,
#              'Rate_name': 'Breakfast Included, Internet Included - '
#                           'Non-refundable',
#              'Room_name': 'Tower Suite',
#              'Top Deal': False},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 6404,
#              'Rate_name': 'Breakfast Included, Internet Included, Meal '
#                           'Included - Non-refundable',
#              'Room_name': 'Tower Suite',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 6991,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Tower Suite',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 14:00 '
#                                     '(GMT+00:00) on Aug 16, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 7250,
#              'Rate_name': 'Breakfast Included, Internet Included',
#              'Room_name': 'Tower Suite',
#              'Top Deal': False}]}
# {'100425': [{'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 771,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Standard Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 18:00 '
#                                     '(GMT+01:00) on Sep 06, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 792,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Standard Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 771,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Patio Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 18:00 '
#                                     '(GMT+01:00) on Sep 06, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 809,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Patio Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 795,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Standard Room, Balcony',
#              'Top Deal': True},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 18:00 '
#                                     '(GMT+01:00) on Sep 06, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 836,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Standard Room, Balcony',
#              'Top Deal': True},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 806,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Large Budget Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 18:00 '
#                                     '(GMT+01:00) on Sep 06, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 829,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Large Budget Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 845,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Superior Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 18:00 '
#                                     '(GMT+01:00) on Sep 06, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 878,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Superior Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 945,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'Executive Studio',
#              'Top Deal': True},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 18:00 '
#                                     '(GMT+01:00) on Sep 06, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 1114,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'Executive Studio',
#              'Top Deal': True}]}
# {'18620': [{'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1159,
#             'Rate_name': 'Deluxe House (Barlow House) - Non-refundable',
#             'Room_name': 'Deluxe House (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1316,
#             'Rate_name': 'Breakfast Included - Non-refundable',
#             'Room_name': 'Deluxe House (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 16:00 '
#                                    '(GMT+01:00) on Aug 07, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1449,
#             'Rate_name': 'Deluxe House (Barlow House)',
#             'Room_name': 'Deluxe House (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 16:00 '
#                                    '(GMT+01:00) on Aug 07, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1645,
#             'Rate_name': 'Breakfast Included',
#             'Room_name': 'Deluxe House (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 16:00 '
#                                    '(GMT+01:00) on Aug 07, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1645,
#             'Rate_name': 'Breakfast Included',
#             'Room_name': 'Deluxe House (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1219,
#             'Rate_name': 'House, 1 King Bed, Non Smoking - Non-refundable',
#             'Room_name': 'House, 1 King Bed, Non Smoking',
#             'Top Deal': False},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1541,
#             'Rate_name': 'Breakfast Included - Non-refundable',
#             'Room_name': 'House, 1 King Bed, Non Smoking',
#             'Top Deal': False},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 16:00 '
#                                    '(GMT+01:00) on Aug 07, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1625,
#             'Rate_name': 'House, 1 King Bed, Non Smoking',
#             'Room_name': 'House, 1 King Bed, Non Smoking',
#             'Top Deal': False},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 16:00 '
#                                    '(GMT+01:00) on Aug 07, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1822,
#             'Rate_name': 'Breakfast Included',
#             'Room_name': 'House, 1 King Bed, Non Smoking',
#             'Top Deal': False},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1415,
#             'Rate_name': 'Superior Double Room, 1 King Bed (Barlow House) - '
#                          'Non-refundable',
#             'Room_name': 'Superior Double Room, 1 King Bed (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1533,
#             'Rate_name': 'Breakfast Included - Non-refundable',
#             'Room_name': 'Superior Double Room, 1 King Bed (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 16:00 '
#                                    '(GMT+01:00) on Aug 07, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 1665,
#             'Rate_name': 'Superior Double Room, 1 King Bed (Barlow House)',
#             'Room_name': 'Superior Double Room, 1 King Bed (Barlow House)',
#             'Top Deal': False},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 16:00 '
# ...
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 506,
#             'Rate_name': 'Internet Included - Non-refundable',
#             'Room_name': 'Standard Twin Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 26, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 563,
#             'Rate_name': 'Internet Included',
#             'Room_name': 'Standard Twin Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 563,
#             'Rate_name': 'Internet Included, Breakfast Included - '
#                          'Non-refundable',
#             'Room_name': 'Standard Twin Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 26, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 625,
#             'Rate_name': 'Internet Included, Breakfast Included',
#             'Room_name': 'Standard Twin Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 619,
#             'Rate_name': 'Internet Included - Non-refundable',
#             'Room_name': 'Standard Triple Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 26, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 688,
#             'Rate_name': 'Internet Included',
#             'Room_name': 'Standard Triple Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 704,
#             'Rate_name': 'Internet Included, Breakfast Included - '
#                          'Non-refundable',
#             'Room_name': 'Standard Triple Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 26, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 782,
#             'Rate_name': 'Internet Included, Breakfast Included',
#             'Room_name': 'Standard Triple Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 732,
#             'Rate_name': 'Internet Included - Non-refundable',
#             'Room_name': 'Standard Quadruple Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 26, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 814,
#             'Rate_name': 'Internet Included',
#             'Room_name': 'Standard Quadruple Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'Non-refundable',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 845,
#             'Rate_name': 'Internet Included, Breakfast Included - '
#                          'Non-refundable',
#             'Room_name': 'Standard Quadruple Room',
#             'Top Deal': True},
#            {'Cancellation Policy': 'This property imposes the following '
#                                    'penalties to its customers that Qantas '
#                                    'Hotels is required to pass on: '
#                                    'Cancellations or changes made after 14:00 '
#                                    '(GMT+01:00) on Aug 26, 2024 are subject to '
#                                    'a 1 night room & tax penalty. If you fail '
#                                    'to check-in for this reservation, or if '
#                                    'you cancel or change this reservation '
#                                    'after check-in, you may incur penalty '
#                                    'charges at the discretion of the property '
#                                    'of up to 100% of the booking value. If you '
#                                    'redeem Qantas Points or a Qantas Voucher '
#                                    'please refer to the relevant Important '
#                                    'Information and Terms & Conditions on the '
#                                    'checkout page.',
#             'Currency': 'AUD',
#             'Number of Guests': 2,
#             'Price': 939,
#             'Rate_name': 'Internet Included, Breakfast Included',
#             'Room_name': 'Standard Quadruple Room',
#             'Top Deal': True}]}
# {'224854': [{'Cancellation Policy': 'Non-refundable',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 965,
#              'Rate_name': 'Internet Included - Non-refundable',
#              'Room_name': 'King Room',
#              'Top Deal': True},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 16:00 '
#                                     '(GMT+01:00) on Sep 24, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 1135,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'King Room',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 16:00 '
#                                     '(GMT+01:00) on Sep 24, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 1284,
#              'Rate_name': 'Internet Included, Breakfast Included',
#              'Room_name': 'King Room',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 16:00 '
#                                     '(GMT+01:00) on Sep 24, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 1255,
#              'Rate_name': 'Internet Included',
#              'Room_name': 'King Room - Tower View',
#              'Top Deal': False},
#             {'Cancellation Policy': 'This property imposes the following '
#                                     'penalties to its customers that Qantas '
#                                     'Hotels is required to pass on: '
#                                     'Cancellations or changes made after 16:00 '
#                                     '(GMT+01:00) on Sep 24, 2024 are subject '
#                                     'to a 1 night room & tax penalty. If you '
#                                     'fail to check-in for this reservation, or '
#                                     'if you cancel or change this reservation '
#                                     'after check-in, you may incur penalty '
#                                     'charges at the discretion of the property '
#                                     'of up to 100% of the booking value. If '
#                                     'you redeem Qantas Points or a Qantas '
#                                     'Voucher please refer to the relevant '
#                                     'Important Information and Terms & '
#                                     'Conditions on the checkout page.',
#              'Currency': 'AUD',
#              'Number of Guests': 2,
#              'Price': 1404,
#              'Rate_name': 'Internet Included, Breakfast Included',
#              'Room_name': 'King Room - Tower View',
#              'Top Deal': False}]}

# %%
df1=pd.read_csv(r"C:\Users\goura\Downloads\output.csv", header=None)
df1.columns=['hotel_id','check-in', 'check-out', 'rates']
df1.to_csv(r"C:\Users\goura\Downloads\output.csv", index=False)
